# %%
import pandas as pd
tides = pd.read_csv('wpb-tides-2017.txt', sep='\t', skiprows=14, header=None,
            usecols=[0,1,2,3,5,7],
            names=['Date', 'Day', 'Time', 'Pred(ft)', 'Pred(cm)', 'High/Low'],
            parse_dates=['Date','Time'])
tides[(tides['High/Low'] == 'H') & (tides['Day'] == 'Sat')]
# Out:
#            Date  Day                Time  Pred(ft)  Pred(cm) High/Low
# 23   2017-01-07  Sat 2017-08-18 03:04:00       2.7        82        H
# 25   2017-01-07  Sat 2017-08-18 15:16:00       2.5        76        H
# 51   2017-01-14  Sat 2017-08-18 09:34:00       3.1        94        H
# 53   2017-01-14  Sat 2017-08-18 21:51:00       2.7        82        H
# 77   2017-01-21  Sat 2017-08-18 03:07:00       2.2        67        H
# 79   2017-01-21  Sat 2017-08-18 15:11:00       1.9        58        H
# 105  2017-01-28  Sat 2017-08-18 08:29:00       2.8        85        H
# 107  2017-01-28  Sat 2017-08-18 20:39:00       2.4        73        H
# 131  2017-02-04  Sat 2017-08-18 01:38:00       2.6        79        H
# 133  2017-02-04  Sat 2017-08-18 13:51:00       2.3        70        H
# 159  2017-02-11  Sat 2017-08-18 08:27:00       3.0        91        H
# 161  2017-02-11  Sat 2017-08-18 20:44:00       2.7        82        H
# ...
